# %% [markdown]
# ## Plotting ZDF data files

# %% [markdown]
# To Plot ZDF data files you must first import the ZDF module

# %%
from zdf import zdf_read_grid

# %% [markdown]
# Next you need to read the data. You should also read the metadata while you are at it.

# %%
(data, info) = zdf_read_grid( "J3-000500.zdf" )

# %% [markdown]
# data is a NumPy ndarray, info is a dictionary with all the Metadata.

# %%
print(type(data))

print(info)
# Out:
# <class 'numpy.ndarray'>
# {'grid': {'ndims': 2, 'nx': [128, 128], 'label': 'J3', 'units': 'e \\omega_p^2 / c', 'has_axis': 1, 'axis': [{'type': 0, 'min': 0.0, 'max': 12.800000190734863, 'label': 'x_1', 'units': 'c/\\omega_p'}, {'type': 0, 'min': 0.0, 'max': 12.800000190734863, 'label': 'x_2', 'units': 'c/\\omega_p'}]}, 'iteration': {'n': 500, 't': 35.0, 'tunits': '1/\\omega_p'}}

# %% [markdown]
# You can plot the data with any of your favorite tools.

# %% [markdown]
# **Plotting with Bokeh**

# %%
import numpy as np
from bokeh.io import push_notebook, show, output_notebook
output_notebook()

from bokeh.plotting import figure
from bokeh.models import LinearColorMapper, BasicTicker, ColorBar
from bokeh.core.enums import TextBaseline

p = figure(x_range=(info['grid']['axis'][0]['min'], info['grid']['axis'][0]['max']), 
           y_range=(info['grid']['axis'][1]['min'], info['grid']['axis'][1]['max']),
           toolbar_sticky=False)
p.title.text = info['grid']['label']

p.xaxis.axis_label = info['grid']['axis'][0]['label']
p.yaxis.axis_label = info['grid']['axis'][1]['label']

color_map = LinearColorMapper(palette="Viridis256", low = np.amin(data), high = np.amax(data))

p.image(image=[data], x = 0, y = 0, 
        dw = info['grid']['axis'][0]['max'], dh = info['grid']['axis'][1]['max'], 
        color_mapper = color_map )

color_bar = ColorBar(color_mapper = color_map, ticker = BasicTicker(),
                     location = (0,0))
p.add_layout( color_bar, 'right')

t = show(p, notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cfb80943-d80d-4595-9cb6-e9729a5e09b5">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="045b365a-82ad-4047-bb41-cf8ed95f83bc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("045b365a-82ad-4047-bb41-cf8ed95f83bc").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("6b078729-f204-4f50-a29e-c6b064b19281", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("045b365a-82ad-4047-bb41-cf8ed95f83bc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '045b365a-82ad-4047-bb41-cf8ed95f83bc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d4a1d83e-9328-49a2-9493-15f2cddfd06d":{"roots":{"references":[{"attributes":{},"id":"74dce4d6-8293-4893-8873-8fb54b3e5ef5","type":"ToolEvents"},{"attributes":{"callback":null,"end":12.800000190734863},"id":"40628452-de2f-47f4-b0eb-174586b9059d","type":"Range1d"},{"attributes":{},"id":"49a368db-b07c-4449-91e2-d9f92cd58519","type":"BasicTicker"},{"attributes":{"callback":null,"end":12.800000190734863},"id":"fa734712-ce72-412c-b031-cf33fcf75778","type":"Range1d"},{"attributes":{"below":[{"id":"dda5589c-b496-493b-be40-d7bffa9aac3c","type":"LinearAxis"}],"left":[{"id":"9a5d982e-e6b4-43c4-b3e0-bd020b3fc599","type":"LinearAxis"}],"renderers":[{"id":"dda5589c-b496-493b-be40-d7bffa9aac3c","type":"LinearAxis"},{"id":"27446b34-c471-4f18-b4c6-6b90a556864d","type":"Grid"},{"id":"9a5d982e-e6b4-43c4-b3e0-bd020b3fc599","type":"LinearAxis"},{"id":"b275c031-0849-4358-a19f-454ea9fb1027","type":"Grid"},{"id":"c7ae8c73-ed76-4a57-8a9d-2e1bcd9774c3","type":"BoxAnnotation"},{"id":"86fd217c-d260-4acf-9bb3-524a2b53fb13","type":"GlyphRenderer"},{"id":"3011bd76-68e7-4373-9d38-94681361c5a9","type":"ColorBar"}],"right":[{"id":"3011bd76-68e7-4373-9d38-94681361c5a9","type":"ColorBar"}],"title":{"id":"763f7044-282b-40a0-a53e-607aaa2bef60","type":"Title"},"tool_events":{"id":"74dce4d6-8293-4893-8873-8fb54b3e5ef5","type":"ToolEvents"},"toolbar":{"id":"882ed343-53a1-4271-8cd3-d769f51ba684","type":"Toolbar"},"toolbar_sticky":false,"x_range":{"id":"40628452-de2f-47f4-b0eb-174586b9059d","type":"Range1d"},"y_range":{"id":"fa734712-ce72-412c-b031-cf33fcf75778","type":"Range1d"}},"id":"563181d2-e52b-4b17-a755-0cc00f85c3fb","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"5c3d75b2-8b62-4d69-b228-6ce23c31ee45","type":"ColumnDataSource"},"glyph":{"id":"5572d022-26d3-45b2-bd43-328f2ee3f7db","type":"Image"},"hover_glyph":null,"nonselection_glyph":{"id":"4d5d10f3-1bf1-4775-bed2-2d3054df115a","type":"Image"},"selection_glyph":null},"id":"86fd217c-d260-4acf-9bb3-524a2b53fb13","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"float64","shape":[128,128]}]}},"id":"5c3d75b2-8b62-4d69-b228-6ce23c31ee45","type":"ColumnDataSource"},{"attributes":{"axis_label":"x_1","formatter":{"id":"3060815b-3d51-4082-93f7-3779c047df55","type":"BasicTickFormatter"},"plot":{"id":"563181d2-e52b-4b17-a755-0cc00f85c3fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"49a368db-b07c-4449-91e2-d9f92cd58519","type":"BasicTicker"}},"id":"dda5589c-b496-493b-be40-d7bffa9aac3c","type":"LinearAxis"},{"attributes":{"color_mapper":{"id":"463352ea-b1c8-4f38-b804-a1beba18ca83","type":"LinearColorMapper"},"dh":{"units":"data","value":12.800000190734863},"dw":{"units":"data","value":12.800000190734863},"image":{"field":"image"},"x":{"value":0},"y":{"value":0}},"id":"4d5d10f3-1bf1-4775-bed2-2d3054df115a","type":"Image"},{"attributes":{"plot":{"id":"563181d2-e52b-4b17-a755-0cc00f85c3fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"49a368db-b07c-4449-91e2-d9f92cd58519","type":"BasicTicker"}},"id":"27446b34-c471-4f18-b4c6-6b90a556864d","type":"Grid"},{"attributes":{"axis_label":"x_2","formatter":{"id":"f61886d2-75ca-419b-b0f0-c7b0136c2638","type":"BasicTickFormatter"},"plot":{"id":"563181d2-e52b-4b17-a755-0cc00f85c3fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"1bef8baa-4541-4844-b97f-3c9ac3db0b0e","type":"BasicTicker"}},"id":"9a5d982e-e6b4-43c4-b3e0-bd020b3fc599","type":"LinearAxis"},{"attributes":{},"id":"1bef8baa-4541-4844-b97f-3c9ac3db0b0e","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"563181d2-e52b-4b17-a755-0cc00f85c3fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"1bef8baa-4541-4844-b97f-3c9ac3db0b0e","type":"BasicTicker"}},"id":"b275c031-0849-4358-a19f-454ea9fb1027","type":"Grid"},{"attributes":{},"id":"f61886d2-75ca-419b-b0f0-c7b0136c2638","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"v ...

# %% [markdown]
# **Plotting with MatplotLib**

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

fig = plt.figure( figsize = (8,6), dpi = 80)
fig.subplots_adjust( top = 0.85 )
fig.set_facecolor("#FFFFFF") 

timeLabel = r'$\sf{t = ' + str( info['iteration']['t'] ) + \
                     ' ['+info['iteration']['tunits']+r']}$'
plotTitle = r'$\sf{' + info['grid']['label'] + r'}$' + '\n' + timeLabel

plotArea = fig.add_subplot(1,1,1)
plotArea.set_title(plotTitle, fontsize = 16)

colorMap = plotArea.imshow(data, cmap = plt.cm.jet, interpolation = 'nearest', 
                           origin = 'lower')

colorBar = fig.colorbar(colorMap)
colorBar.set_label(r'$\sf{'+info['grid']['label'] +
        ' [' + info['grid']['units'] + r']}$', fontsize = 14)

xlabel = info['grid']['axis'][0]['label'] + '[' + info['grid']['axis'][0]['units'] + ']'
ylabel = info['grid']['axis'][1]['label'] + '[' + info['grid']['axis'][1]['units'] + ']'
plt.xlabel(r'$\sf{'+xlabel+r'}$', fontsize = 14)
plt.ylabel(r'$\sf{'+ylabel+r'}$', fontsize = 14)
# Out:
# <img src="data:image/png;base64,..." width="640">
